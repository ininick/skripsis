# %% [markdown]
# ### TRAINING SEED (MANUAL LABELED) DATA

# %%
# !pip install -U scikit-learn transformers torch sastrawi tqdm matplotlib

# %%
import pandas as pd

TRAIN_DATA_PATH = '../../data/data_berita/train_data/'

# %%
df1 = pd.read_csv(f"{TRAIN_DATA_PATH}/cnbc_train_data.csv")
df2 = pd.read_csv(f"{TRAIN_DATA_PATH}/detik_train_data.csv")
df3 = pd.read_csv(f"{TRAIN_DATA_PATH}/kompas_train_data.csv")

print(df1.columns)
display(df1.head())
print(df2.columns)
display(df2.head())
print(df3.columns)
display(df3.head())
# Out:
# Index(['date', 'title', 'content', 'article_id', 'text', 'label'], dtype='object')
#          date                                              title  \
# 0  2019-09-11  menko luhut jokowi tak mungkin asal pilih ment...
# 1  2019-09-24  ini siasat lobi-lobi boris saat brexit makin u...
# 2  2019-10-06  menterinya terbanyak se-asean, kabinet ri baka...
# 3  2019-10-16             akankah gerindra masuk koalisi jokowi?
# 4  2019-10-16  kubu prabowo masuk koalisi jokowi, berkah atau...
#
#                                              content  article_id  \
# 0  jakarta, cnbc indonesia- presiden joko widodo ...  CNBC_00008
# 1  jakarta, cnbc indonesia-kurang dari 40 hari je...  CNBC_00012
# 2  cnbc indonesia, jakarta -jelang pelantikan kab...  CNBC_00017
# 3  jakarta, cnbc indonesia -partai gerindra mengg...  CNBC_00023
# 4  berbicara mengenai perekonomian, investasi men...  CNBC_00026
#
#                                                 text  label
# 0  menko luhut jokowi tak mungkin asal pilih ment...      0
# 1  ini siasat lobi-lobi boris saat brexit makin u...      0
# 2  menterinya terbanyak se-asean, kabinet ri baka...      0
# 3  akankah gerindra masuk koalisi jokowi?. jakart...      0
# 4  kubu prabowo masuk koalisi jokowi, berkah atau...      1
# Index(['date', 'title', 'content', 'text', 'label', 'article_id'], dtype='object')
#          date                                              title  \
# 0  2023-12-20  mendagri copot pj bupati kampar karena tak net...
# 1  2025-06-20  waka mpr nilai keputusan prabowo absen di g7 j...
# 2  2024-02-14  setelah nyoblos, ahy bakal merapat ke istora s...
# 3  2024-06-05  obrolan jk dan baradar jika diizinkan saya ban...
# 4  2023-10-31  golkar masih lobi khofifah gabung tkn prabowo-...
#
#                                              content  \
# 0  menteri dalam negeri mendagri tito karnavian m...
# 1  wakil ketua mpr dari fraksi pan, eddy soeparno...
# 2  tim kampanye nasional tkn prabowo-gibran bakal...
# 3  wakil perdana menteri 1 afghanistan mullah abd...
# 4  sekjen partai golkar lodewijk f paulus berbica...
#
#                                                 text  label  article_id
# 0  mendagri copot pj bupati kampar karena tak net...     -1  DETIK_7302
# 1  waka mpr nilai keputusan prabowo absen di g7 j...      0  DETIK_1543
# 2  setelah nyoblos, ahy bakal merapat ke istora s...      0  DETIK_6055
# 3  obrolan jk dan baradar jika diizinkan saya ban...      0  DETIK_4993
# 4  golkar masih lobi khofifah gabung tkn prabowo-...      0  DETIK_8269
# Index(['date', 'title', 'content', 'label', 'article_id', 'text'], dtype='object')
#          date                                              title  \
# 0  2022-01-23  polemik arteria dahlan jadi pembelajaran kader...
# 1  2022-01-23  hut ke-75 megawati, pramono anung politik ibu ...
# 2  2022-01-24  pengamat tebak pesan anies ke giring kalau sum...
# 3  2022-01-24    update 20.867 kasus aktif covid-19 di indonesia
# 4  2022-01-25  update 25 januari 7.483 kasus suspek covid-19 ...
#
#                                              content  label   article_id  \
# 0   sekretaris jenderal pdi-p hasto kristiyanto m...      0  KOMPAS_9963
# 1   mantan sekretaris jenderal pdi perjuangan pra...      0  KOMPAS_9962
# 2   direktur eksekutif parameter politik indonesi...      0  KOMPAS_9956
# 3   pemerintah menyampaikan terdapat 20.867 kasus...     -1  KOMPAS_9945
# 4   pemerintah mencatat, hingga selasa 25 1 2022 ...     -1  KOMPAS_9936
#
#                                                 text
# 0  polemik arteria dahlan jadi pembelajaran kader...
# 1  hut ke-75 megawati, pramono anung politik ibu ...
# 2  pengamat tebak pesan anies ke giring kalau sum...
# 3  update 20.867 kasus aktif covid-19 di indonesi...
# 4  update 25 januari 7.483 kasus suspek covid-19 ...

# %%
# =========================
# Core
# =========================
import os
import re
import math
import random
from dataclasses import dataclass
from typing import List, Dict, Optional, Tuple

# =========================
# Data / Numeric
# =========================
import numpy as np
import pandas as pd

# =========================
# Visualization (optional)
# =========================
import matplotlib.pyplot as plt

# =========================
# Sklearn (split + metrics)
# =========================
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    f1_score,
    precision_recall_fscore_support
)

# =========================
# PyTorch
# =========================
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# =========================
# Hugging Face Transformers (IndoBERT)
# =========================
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    DataCollatorWithPadding,
    TrainingArguments,
    Trainer,
    set_seed
)

# =========================
# (Optional) Sastrawi
# =========================
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# =========================
# (Optional) Progress bar
# =========================
from tqdm.auto import tqdm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 25
#      20 import matplotlib.pyplot as plt
#      22 # =========================
#      23 # Sklearn (split + metrics)
#      24 # =========================
# ---> 25 from sklearn.model_selection import train_test_split
#      26 from sklearn.metrics import (
#      27     classification_report,
#      28     confusion_matrix,
#    (...)     31     precision_recall_fscore_support
#      32 )
#      34 # =========================
#      35 # PyTorch
#      36 # =========================
#
# ModuleNotFoundError: No module named 'sklearn'
